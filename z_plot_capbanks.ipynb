# %%
import cmath
import numpy as np
import matplotlib.pyplot as plt

from capacitor_multibank import Zcapbanks

# %% [markdown]
# ### next steps:
# - work on ac current divider model
# - add voltage derating curves to cap definition
# - create xlsx table of capacitors....like was done with inductors and fets

# %%
Csp   = {'type':'sp',  'C':10e-6,  'ESR':500e-3, 'ESL':2e-9,   'n':1}
Cmlcc = {'type':'mlcc','C':1.6e-6, 'ESR':5e-3,   'ESL':0.5e-9, 'n':10}

Caplist = [Csp,Cmlcc]

# %%
zcapbanks = Zcapbanks(Caplist)

# %%
zcapbanks.plot_Zbanks()
